# %% [markdown]
# #### 技能
#
#     熟悉数据库、数据仓库；
#     熟悉python，hadoop, hive，spark等；
#     熟练运用各种常用算法和数据结构，有独立的实现能力
#     熟悉机器学习、数据挖掘、数据分析、分布式计算；
#     增长黑客(Growth Hacking)
#     大数据分析/BI/OLAP后台系统研发；
#
# #### 职责
#     大数据风控、精准营销等方面的数据分析、挖掘及服务支持；
#     规划搭建数据指标体系和分析体系，以强数据导向推动短视频的增长目标；
#     拆解用户增长、留存、拉新、转化、ARPU 提升等细分目标；
#     分析用户行为、趋势以及大量AB测试小流量实验结果数据，充分利用机器学习对多维数据（PV,UV,时长等）关联分析。
#
#
#     能独立承担风险问题的研究落地：风险分析、原因追溯、策略及模型设计、效果评估等。 ======== 风险策略及分析
#
#     1. 负责腾讯云收入、损益、账款等行业数据运营，数据分析，模型建立，波动预测；
#
#     2. 善于总结、归纳及沉淀经验，以行业运营数据为切入点，提炼数据观点以用数据指导运营；
#
#     3. 腾讯云行业数据需求统筹规划，提出数据产品需求，跟进数据项目落地
#
#     －参与腾讯游戏数据平台元数据管理系统的开发；
#
#     －参与腾讯游戏数据平台数据质量、数据流监控的开发；
#
#     －参与腾讯游戏数据平台数据分析模块的开发。
#
#
#     负责广告安全相关产品的数据运营和项目管理工作，包括日常运营数据的异常分析及解决、测试方案选择、策略影响评估、项目开发进度跟踪。
#
#     监控和提升重点数据，能从数据变化中主动发现问题，推动解决
#
#     关注广告行业的发展，结合平台能力，产出对行业和客户有影响力的专题分析报告。
